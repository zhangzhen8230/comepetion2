# %%
import pandas as pd
en_train = pd.read_table('../data/cikm_english_train_20180516.txt',names=['en1','sp1','en2','sp2','label'])
sp_train = pd.read_table('../data/cikm_spanish_train_20180516.txt',names=['sp1','en1','sp2','en2','label'])
unlabel_sp_train = pd.read_table('../data/cikm_unlabel_spanish_train_20180516.txt',names=['sp1','en1','sp2','en2','label'])
test = pd.read_table('../data/cikm_test_a_20180516.txt',names=['sp1','sp2'])

df_all = pd.concat((en_train,sp_train))

df_all['sp1'].fillna('', inplace=True)
df_all['sp2'].fillna('', inplace=True)
test
# Out:
#                                                     sp1  \
# 0     ?Cómo puedo recibir un reembolso mediante tarj...
# 1     ?Cómo puedo recibir un reembolso mediante tarj...
# 2     ?No he podido pagar con mi tarjeta, que debo h...
# 3     ?No he podido pagar con mi tarjeta, que debo h...
# 4     ?No he podido pagar con mi tarjeta, que debo h...
# 5     ?Por qué no se ha podido procesar mi pago por ...
# 6     ?Cuándo recibiré mi reembolso si pago con tarj...
# 7             ?Qué pasará después de abrir una disputa?
# 8             ?Qué pasará después de abrir una disputa?
# 9     ?Por qué ha sido finalizado mi pedido por razo...
# 10    El producto que he recibido no corresponde con...
# 11                    ?Por qué se ha cerrado mi pedido?
# 12                    ?Por qué se ha cerrado mi pedido?
# 13                    ?Por qué se ha cerrado mi pedido?
# 14                    ?Por qué se ha cerrado mi pedido?
# 15     ?Cómo utilizo el Servicio de Garantía de un Año?
# 16     ?Cómo utilizo el Servicio de Garantía de un Año?
# 17    ?Como puedo pagar con mi tarjeta de credito/de...
# 18    ?Como puedo pagar con mi tarjeta de credito/de...
# 19    ?Por qué mi pedido está en verificación tras e...
# 20         ?Por qué tarda tanto que mi pago se procese?
# 21                  ?Por qué se ha congelado mi pedido?
# 22           ?Por qué no puedo usar mi Cupón Selección?
# 23           ?Por qué no puedo usar mi Cupón Selección?
# 24    ?Cómo puedo recibir un reembolso con la tarjet...
# 25    ?Cómo puedo recibir un reembolso con la tarjet...
# 26             ?Como puedo pagar mediante Mercado Pago?
# 27    El producto recibido no es bueno, no funciona,...
# 28                         ?Cómo encuentro un producto?
# 29                         ?Cómo encuentro un producto?
# ...                                                 ...
# 4970                          utilice visa y mastercard
# 4971  ya he pagado en el banco la suma acordada pero...
# 4972            YA LE ENVIE MENSAJE PERO NO ME RESPONDE
# 4973                yo solo quiero hablar con un agente
# 4974  504375784787386 este pedido lleva congelado mu...
# 4975  abro disputa por reembolso o por devolucion de...
# 4976  Acabo de hacer un pedido y no me deja realizar...
# 4977  Acabo de meter el numero de tarjeta y pague y ...
# 4978  acabo de recibir un producto que no es lo que ...
# 4979  acordé un reembolso pero no sé donde debo revisar
# 4980  ahi dice que se realizo la entrega de mi pedid...
# 4981                        alguien ha usado mi tarjeta
# 4982  Alguien ha usado mi tarjeta y ha hecho un pedi...
# 4983  Anoté la dirección incorrecta, ¿cómo puedo cam...
# 4984  ayer contacte con ustedes por un problema con ...
# 4985  ayer hice pedido de marcos de lentes y ahora n...
# 4986                    ayuda porfavor con un asistente
# 4987          Ayúdame a saber el estado de mi apelación
# 4988  buenas noches el pedido recibido llego en mal ...
# 4989  Buenas Noches: La disputa ya lo realice pero a...
# 4990  buenas tardes!! quisiera saber porqué tarda ta...
# 4991  Buenas, necesito justificante de pago de mi pe...
# 4992             buenos dias no he recibido este pedido
# 4993                         Caros pedido no an llegado
# 4994           Como Le ago para poner una targeta nueva
# 4995  Como puedo abrir disputa! El vendedor no contesta
# 4996                     como puedo hablar co un agente
# 4997                       Como puedo hablar con humano
# 4998                       Como puedo hablar con humano
# 4999                       Como puedo hablar con humano
#
#                                                     sp2
# 0                     ¿Cómo puedo recibir un reembolso?
# 1     ¿Cómo puedo recibir un reembolso si mi banco h...
# 2     No puedo pagar con mi tarjeta de débito, ¿qué ...
# 3     No puedo pagar mi pedido con tarjeta Visa de d...
# 4                           No puedo pagar con tarjeta.
# 5     ¿Por qué el pedido ha sido cerrado por razones...
# 6     ¿Me cobran tarifa de servicio si pago mis pedi...
# 7            ¿Qué pasará después de escalar la disputa?
# 8                             Quiero abrir una disputa.
# 9     ¿Por qué mi pedido está cerrado otra vez por r...
# 10    He pagado con mi tarjeta de crédito dos veces ...
# 11               ¿Por qué no se ha cancelado mi pedido?
# 12    He pagado, pero el pedido se ha cerrado por no...
# 13           ¿Por qué dice "Su pedido ha sido cerrado"?
# 14             ¿Por qué mi transacción se ha congelado?
# 15         ¿Cómo uso el Servicio de Garantía de un año?
# 16                   ¿Cómo uso el Servicio de Garantía?
# 17    ¿Puedo pagar mi pedido con mi tarjeta de crédi...
# 18              ¿Puedo pagar con tarjeta de débito BMO?
# 19    ¿Por qué mi pedido está cerrado con el pago de...
# 20                       ¿Por qué mi envío tarda tanto?
# 21                  ¿Por qué se ha cancelado el pedido?
# 22                        ¿Por qué no puedo usar PayPal
# 23        ¿Por qué no puedo usar mi tarjeta de crédito?
# 24    ¿Cómo recibo un reembolso por tarjeta de crédito?
# 25    ¿Cómo puedo pagar los productos con tarjeta de...
# 26            ¿Por qué no puedo pagar con Mercado Pago?
# 27           El paquete no es el mío. ¿Qué puedo hacer?
# 28                         ¿Cómo encuentro un vendedor?
# 29                         ¿Cómo encuentro compradores?
# ...                                                 ...
# 4970                      Tarjeta MasterCard de débito.
# 4971  Se me ha cobrado el pago, pero no está refleja...
# 4972  ¡Envío un montón de mensajes al vendedor, pero...
# 4973    Quiero hablar con una persona, no con un robot.
# 4974                         Se ha congelado el pedido.
# 4975                  Quiero una disputa por mi pedido.
# 4976  Estoy intentando hacer un pedido y, por alguna...
# 4977  Me han cobrado, pero el pedido sigue pendiente...
# 4978     El producto no es lo que quería o lo que pedí.
# 4979                ¿Dónde debo comprobar mi reembolso?
# 4980  En el sitio web dice que mi pedido ya ha sido ...
# 4981         No hice un pedido. Alguien usó mi tarjeta.
# 4982         No hice un pedido. Alguien usó mi tarjeta.
# 4983  He introducido una dirección incorrecta. ¿Cómo...
# 4984                   Tengo un problema con el pedido.
# 4985  Hice un pedido y no puedo encontrarlo en mis p...
# 4986                      Necesito un asistente humano.
# 4987          Quiero saber el estado de mi reclamación.
# 4988  He recibido el artículo en muy malas condiciones.
# 4989  El vendedor está siempre offline y no responde...
# 4990     ¿Por qué mi pago tarda tanto en ser procesado?
# 4991       Necesito una copia de la factura de mi pago.
# 4992                  No he recibido el pedido enviado.
# 4993                       El pedido aún no ha llegado.
# 4994  Guardé mi tarjeta de crédito, pero necesito re...
# 4995                           El vendedor no contesta.
# 4996                     Necesito hablar con un humano.
# 4997                   Necesito hablar con una persona.
# 4998  Necesito hablar con los representantes de ventas.
# 4999           Necesito hablar con atención al cliente.
#
# [5000 rows x 2 columns]

# %% [markdown]
# creat vocab

# %%
from sklearn.feature_extraction.text import CountVectorizer
import itertools

counts_vectorizer = CountVectorizer(max_features=10000-1).fit(
    itertools.chain(df_all['sp1'], df_all['sp2'],test['sp1'],test['sp2']))
other_index = len(counts_vectorizer.vocabulary_)

# %% [markdown]
# prep data

# %%
import re
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
words_tokenizer = re.compile(counts_vectorizer.token_pattern)

def create_padded_seqs(texts, max_len=10):
    seqs = texts.apply(lambda s:
        [counts_vectorizer.vocabulary_[w] if w in counts_vectorizer.vocabulary_ else other_index
         for w in words_tokenizer.findall(s.lower())])
    return pad_sequences(seqs, maxlen=max_len)

# df_all = df_all.sample(1000) # Just for debugging
print(create_padded_seqs(df_all[:]['sp1']))

X1_train, X1_val, X2_train, X2_val, y_train, y_val = \
    train_test_split(create_padded_seqs(df_all[:]['sp1']),
                     create_padded_seqs(df_all[:]['sp2']),
                     df_all['label'],
                     test_size=0.3, random_state=27)
# Out:
# [[   0    0    0 ... 2086 4297 4558]
#  [4415 4983 4515 ... 4639 2086 1927]
#  [1627 2360 2360 ... 3976 1627 1103]
#  ...
#  [   0    0    0 ... 3394 3540 1972]
#  [   0    0    0 ... 3394 3540 1972]
#  [   0    0    0 ...  890 2358 1532]]

# %% [markdown]
# training

# %%
import keras.layers as lyr
from keras.models import Model

input1_tensor = lyr.Input(X1_train.shape[1:])
input2_tensor = lyr.Input(X2_train.shape[1:])

words_embedding_layer = lyr.Embedding(len(counts_vectorizer.vocabulary_) + 1, 100)
seq_embedding_layer = lyr.LSTM(256, activation='tanh')

seq_embedding = lambda tensor: seq_embedding_layer(words_embedding_layer(tensor))

merge_layer = lyr.multiply([seq_embedding(input1_tensor), seq_embedding(input2_tensor)])

dense1_layer = lyr.Dense(16, activation='sigmoid')(merge_layer)
ouput_layer = lyr.Dense(1, activation='sigmoid')(dense1_layer)

model = Model([input1_tensor, input2_tensor], ouput_layer)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

model.fit([X1_train, X2_train], y_train,
          validation_data=([X1_val, X2_val], y_val),
          batch_size=128, epochs=6, verbose=1)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 10)           0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            (None, 10)           0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 10, 100)      589500      input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 256)          365568      embedding_3[0][0]
#                                                                  embedding_3[1][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 256)          0           lstm_3[0][0]
#                                                                  lstm_3[1][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           4112        multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            17          dense_5[0][0]
# ==================================================================================================
# Total params: 959,197
# Trainable params: 959,197
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 14980 samples, validate on 6420 samples
# Epoch 1/6
# 14980/14980 [==============================] - 20s 1ms/step - loss: 0.5878 - acc: 0.6759 - val_loss: 0.5363 - val_acc: 0.7474
# Epoch 2/6
# 14980/14980 [==============================] - 17s 1ms/step - loss: 0.4859 - acc: 0.7830 - val_loss: 0.4877 - val_acc: 0.7869
# Epoch 3/6
# 14980/14980 [==============================] - 17s 1ms/step - loss: 0.4493 - acc: 0.7974 - val_loss: 0.4816 - val_acc: 0.7874
# Epoch 4/6
# 14980/14980 [==============================] - 18s 1ms/step - loss: 0.4323 - acc: 0.8079 - val_loss: 0.4809 - val_acc: 0.7854
# Epoch 5/6
# 14980/14980 [==============================] - 18s 1ms/step - loss: 0.4132 - acc: 0.8186 - val_loss: 0.4801 - val_acc: 0.7860
# Epoch 6/6
# 14980/14980 [==============================] - 18s 1ms/step - loss: 0.4015 - acc: 0.8224 - val_loss: 0.4818 - val_acc: 0.7829

# %% [markdown]
# Extract Features From Model

# %%
features_model = Model([input1_tensor, input2_tensor], merge_layer)
features_model.compile(loss='mse', optimizer='adam')

# %%
F_train = features_model.predict([X1_train, X2_train], batch_size=128)
F_val = features_model.predict([X1_val, X2_val], batch_size=128)

# %%
import xgboost as xgb

# %%
dTrain = xgb.DMatrix(F_train, label=y_train)
dVal = xgb.DMatrix(F_val, label=y_val)

# %% [markdown]
# Train XGB

# %%
xgb_params = {
    'objective': 'binary:logistic',
    'booster': 'gbtree',
    'eval_metric': 'logloss',
    'eta': 0.1, 
    'max_depth': 9,
    'subsample': 0.9,
    'colsample_bytree': 1 / F_train.shape[1]**0.5,
    'min_child_weight': 5,
    'silent': 1
}
bst = xgb.train(xgb_params, dTrain, 1000,  [(dTrain,'train'), (dVal,'val')], 
                verbose_eval=10, early_stopping_rounds=10)
# Out:
# [0]	train-logloss:0.639288	val-logloss:0.651641
# Multiple eval metrics have been passed: 'val-logloss' will be used for early stopping.
#
# Will train until val-logloss hasn't improved in 10 rounds.
# [10]	train-logloss:0.393243	val-logloss:0.490058
# [20]	train-logloss:0.319254	val-logloss:0.469478
# [30]	train-logloss:0.288414	val-logloss:0.473671
# Stopping. Best iteration:
# [21]	train-logloss:0.314356	val-logloss:0.469072

# %% [markdown]
# Predict Test

# %%
X1_test = create_padded_seqs(test[:]['sp1'])
X2_test = create_padded_seqs(test[:]['sp2'])
F_test = features_model.predict([X1_test, X2_test], batch_size=128)

# %%
dTest = xgb.DMatrix(F_test)
df_sub = pd.DataFrame({ 'score':bst.predict(dTest, ntree_limit=bst.best_ntree_limit)
    })

# %%
import datetime
unique_flag = datetime.datetime.now().strftime('%d_%H_%M')
print(unique_flag)
df_sub.head()
df_sub.to_csv('../result/submit_{}.csv'.format(unique_flag),header=False,index=False)
# df_sub.to_csv('../result/submit.csv',header=False,index=False)
# Out:
# 29_20_16

# %%
import numpy as np 
def log_loss(true_y,pred_h):
    return -np.mean(true_y*np.log(pred_h)+(1-true_y)*np.log(1-pred_h))
